# %% [markdown]
# # Research Quickstart
# Use this notebook to prototype analytics against the local API.

# %%
import requests
import pandas as pd

API_URL = 'http://backend:8000/api/v1'
response = requests.get(f'{API_URL}/strategies')
response.raise_for_status()
pd.DataFrame(response.json())
